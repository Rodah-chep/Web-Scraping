# %%
import requests
import time
import pandas as pd
import re   
from bs4 import BeautifulSoup

# %%
# scrape_all_pages_Cash exchange.py
# Reuse existing notebook imports and helpers (scraper, extract_maprows_info, pd, time, re, max_retries, timeout)

# helper: normalize mapRows / brands HTML into a list of records
def extract_maprows_info(parsed):
    """
    Accepts parsed response (dict from .json() or raw HTML string) and returns
    a list of normalized record dicts. This is tolerant to several payload shapes:
      - dict with 'mapRows' -> {'data': [...]}
      - dict with 'brands' containing HTML
      - raw HTML containing brand blocks with data-brand attributes
    Returns [] on failure.
    """
    records = []
    try:
        # case: JSON dict with mapRows.data as list
        if isinstance(parsed, dict):
            mr = parsed.get("mapRows")
            if isinstance(mr, dict):
                data = mr.get("data")
                if isinstance(data, list) and data:
                    return data
            # sometimes there's a top-level 'data' list
            if isinstance(parsed.get("data"), list):
                return parsed.get("data")
            # try HTML inside 'brands' key
            brands_html = parsed.get("brands")
            if isinstance(brands_html, str):
                parsed = brands_html  # fall through to HTML parsing

        # case: parsed is HTML string -> use BeautifulSoup to extract blocks
        if isinstance(parsed, str):
            soup = BeautifulSoup(parsed, "html.parser")
            # common container class used on site: category__top__item (fallback to any element with data-brand)
            items = soup.find_all("div", class_=re.compile(r"category__top__item|category__item|category-item"))
            if not items:
                items = soup.find_all(attrs={"data-brand": True})
            for div in items:
                rec = {}
                rec["id"] = div.get("data-brand") or div.get("data-id") or None
                a = div.find("a")
                if a:
                    rec["url"] = a.get("href")
                    # try to get a title element if present
                    title = a.find(["h1", "h2", "h3", "h4", "h5"])
                    if title:
                        rec["name"] = title.get_text(strip=True)
                    else:
                        # fallback to anchor/text content
                        rec["name"] = a.get_text(separator=" ", strip=True)
                else:
                    rec["url"] = None
                    rec["name"] = div.get_text(separator=" ", strip=True)
                # optional image
                img = div.find("img")
                if img:
                    rec["image"] = img.get("src") or img.get("data-src")
                    if not rec.get("name"):
                        rec["name"] = img.get("alt")
                # include raw snippet for diagnostics
                rec["raw_html"] = str(div)
                records.append(rec)
            return records
    except Exception as e:
        # keep function safe for use in loops
        print("extract_maprows_info parse error:", e)
    return records


# ensure scraper is available
if "scraper" not in globals():
    try:
        scraper = cloudscraper.create_scraper()
    except Exception:
        raise RuntimeError("cloudscraper not available to create scraper")

# determine base URL (use existing `url` if present)
if "url" in globals() and isinstance(url, str):
    base_url = url
else:
    base_url = "https://www.wheree.com/get-brands?categories%5B%5D=248&page=1&category_id=245&category_slug=Automotive&location_id=231&location_level=0&location_slug=United_States"

# pages to fetch: 1..602
pages = list(range(1,603))

# retry/backoff settings (reuse if defined)
_retries = globals().get("max_retries", 5)
_timeout = globals().get("timeout", 60)
_backoff = 2

all_records = []

for p in pages:
    # build page URL by replacing page=... or appending if missing
    if re.search(r"page=\d+", base_url):
        page_url = re.sub(r"page=\d+", f"page={p}", base_url)
    else:
        sep = "&" if "?" in base_url else "?"
        page_url = f"{base_url}{sep}page={p}"

    resp = None
    for attempt in range(1, _retries + 1):
        try:
            resp = scraper.get(page_url, timeout=_timeout)
            resp.raise_for_status()
            break
        except Exception as e:
            print(f"[page {p}] attempt {attempt} failed: {e}")
            if attempt < _retries:
                time.sleep(_backoff * attempt)
            else:
                print(f"[page {p}] max retries reached, skipping page.")
    if resp is None:
        continue

    # try to parse JSON; prefer resp.json() but fall back to text for extract_maprows_info
    parsed = None
    try:
        parsed = resp.json()
    except Exception:
        parsed = resp.text

    # use existing extract_maprows_info (defined in notebook) to normalize records
    try:
        recs = extract_maprows_info(parsed)
    except Exception as e:
        print(f"[page {p}] extract_maprows_info failed: {e}")
        recs = []

    if not recs:
        print(f"[page {p}] no records extracted")
    else:
        all_records.extend(recs)
        print(f"[page {p}] extracted {len(recs)} records (total so far: {len(all_records)})")

# build dataframe and save
if not all_records:
    print("No records collected from pages 1..20.")
else:
    df_all = pd.DataFrame(all_records)
    out_fname = "gas stations.csv"
    df_all.to_csv(out_fname, index=False)
    display(df_all.head(20))
    print(f"Saved {len(df_all)} records to {out_fname}") 
# Reuse existing notebook imports and helpers (scraper, extract_maprows_info, pd, time, re, max_retries, timeout)
# Out:
# [page 1] extracted 10 records (total so far: 10)
# [page 2] extracted 10 records (total so far: 20)
# [page 3] extracted 10 records (total so far: 30)
# [page 4] extracted 10 records (total so far: 40)
# [page 5] extracted 10 records (total so far: 50)
# [page 6] extracted 10 records (total so far: 60)
# [page 7] extracted 10 records (total so far: 70)
# [page 8] extracted 10 records (total so far: 80)
# [page 9] extracted 10 records (total so far: 90)
# [page 10] extracted 10 records (total so far: 100)
# [page 11] extracted 10 records (total so far: 110)
# [page 12] extracted 10 records (total so far: 120)
# [page 13] extracted 10 records (total so far: 130)
# [page 14] extracted 10 records (total so far: 140)
# [page 15] extracted 10 records (total so far: 150)
# [page 16] extracted 10 records (total so far: 160)
# [page 17] extracted 10 records (total so far: 170)
# [page 18] extracted 10 records (total so far: 180)
# [page 19] extracted 10 records (total so far: 190)
# [page 20] extracted 10 records (total so far: 200)
# [page 21] extracted 10 records (total so far: 210)
# [page 22] extracted 10 records (total so far: 220)
# [page 23] extracted 10 records (total so far: 230)
# [page 24] extracted 10 records (total so far: 240)
# [page 25] extracted 10 records (total so far: 250)
# [page 26] extracted 10 records (total so far: 260)
# [page 27] extracted 10 records (total so far: 270)
# [page 28] extracted 10 records (total so far: 280)
# [page 29] extracted 10 records (total so far: 290)
# [page 30] extracted 10 records (total so far: 300)
# [page 31] extracted 10 records (total so far: 310)
# [page 32] extracted 10 records (total so far: 320)
# [page 33] extracted 10 records (total so far: 330)
# [page 34] extracted 10 records (total so far: 340)
# [page 35] extracted 10 records (total so far: 350)
# [page 36] extracted 10 records (total so far: 360)
# [page 37] extracted 10 records (total so far: 370)
# [page 38] extracted 10 records (total so far: 380)
# [page 39] extracted 10 records (total so far: 390)
# [page 40] extracted 10 records (total so far: 400)
# [page 41] extracted 10 records (total so far: 410)
# [page 42] extracted 10 records (total so far: 420)
# [page 43] extracted 10 records (total so far: 430)
# [page 44] extracted 10 records (total so far: 440)
# [page 45] extracted 10 records (total so far: 450)
# [page 46] extracted 10 records (total so far: 460)
# [page 47] extracted 10 records (total so far: 470)
# [page 48] extracted 10 records (total so far: 480)
# [page 593] extracted 10 records (total so far: 5930)
# [page 594] extracted 10 records (total so far: 5940)
# [page 595] extracted 10 records (total so far: 5950)
# [page 596] extracted 10 records (total so far: 5960)
# [page 597] extracted 10 records (total so far: 5970)
# [page 598] extracted 10 records (total so far: 5980)
# [page 599] extracted 10 records (total so far: 5990)
# [page 600] extracted 10 records (total so far: 6000)
# [page 601] extracted 10 records (total so far: 6010)
# [page 602] extracted 3 records (total so far: 6013)
#          id                                               name  \
# 0   1313022                                Petro Travel Center
# 1   1205397        AutoExpress Service Center-Beltsville Exxon
# 2    193653                          Bill Dodge Nissan Of Saco
# 3    121626                                   Famoso Dragstrip
# 4   1315628                                 Costco Gas Station
# 5   1192415  Costa Oil - 10 Minute Oil Change - Peachtree City
# 6    215061                                        Spoken Moto
# 7    326016                        Edgewater Motor Sports Park
# 8    196347                                       Bostongarage
# 9    270441                             Ridge Motorsports Park
# 10   103440                                                Rxo
# 11   166452                                 Costco Gas Station
# 12  1321245                                 Costco Gas Station
# 13   194519                        Nucar Volkswagen Of Norwood
# 14   103210  Air Team Vehicle Emissions Testing Station - C...
# 15   169020                                 Costco Gas Station
# 16  5376110                           Great Sand Dunes Parking
# 17    27407        High Country Tire/ Full Service Gas Station
# 18   171450                                 Costco Gas Station
# 19   613269                                 Costco Gas Station
#
#                                           fulladdress  \
# 0   970 S Blake Ranch Rd, Kingman, AZ 86401, Unite...
# 1   11055 Baltimore Ave, Beltsville, MD 20705, Uni...
# 2      852 Portland Rd, Saco, ME 04072, United States
# 3   33559 Famoso Rd, McFarland, CA 93250, United S...
# 4   3075 Hamrick Rd, Central Point, OR 97502, Unit...
# 5   100c Petrol Point, Peachtree City, GA 30269, U...
# 6   310 SW Industrial Way, Bend, OR 97702, United ...
# 7   4819 E Miami River Rd, Cleves, OH 45002, Unite...
# 8    145 Webster St, Hanover, MA 02339, United States
# 9   1060 W Eells Hill Rd, Shelton, WA 98584, Unite...
# 10  1600-1620 Atlantic St, Union City, CA 94587, U...
# 11  1709 Automation Pkwy, San Jose, CA 95131, Unit...
# 12  6720 NE 84th St, Vancouver, WA 98665, United S...
# 13  1280 Providence Hwy, Norwood, MA 02062, United...
# 14  195 Liberty Rd, Crystal Lake, IL 60014, United...
# 15  18109 33rd Ave W, Lynnwood, WA 98037, United S...
# 16  Parking lot, Unnamed Rd, Mosca, CO 81146, Unit...
# 17        8227 US-441, Sylva, NC 28779, United States
# 18  15901 SW Jenkins Rd, Aloha, OR 97006, United S...
# 19  101 N Beach Blvd, La Habra, CA 90631, United S...
#
#                                                 alias     ranking  rating  \
# 0                               petro-travel-center-1  1193306901     0.0
# 1          autoexpress-service-centerbeltsville-exxon  1075321725     0.0
# 2                           bill-dodge-nissan-of-saco  1030719166     0.0
# 3                                    famoso-dragstrip   986049381     0.0
# 4                          costco-gas-station-1315628   944545774     0.0
# 5       costa-oil-10-minute-oil-change-peachtree-city   910156250     0.0
# 6                                         spoken-moto   878517421     0.0
# 7                         edgewater-motor-sports-park   848300899     0.0
# 8                                        bostongarage   843750000     0.0
# 9                              ridge-motorsports-park   812488723     0.0
# 10                                                rxo   808012202     0.0
# 11                               costco-gas-station-6   783861638     0.0
# 12                         costco-gas-station-1321245   757651053     0.0
# 13                        nucar-volkswagen-of-norwood   750627197     0.0
# 14  air-team-vehicle-emissions-testing-station-cry...   743817072     0.0
# 15                              costco-gas-station-11   737506982     0.0
# 16                           great-sand-dunes-parking   722958021     4.7
# 17         high-country-tire-full-service-gas-station   720938710     0.0
# 18                              costco-gas-station-16   709528720     0.0
# 19                              costco-gas-station-21   709164102     0.0
#
#     number_of_rates  price_level                   created_at   longitude  \
# 0                 0            0  2025-01-15T00:33:56.000000Z -113.788806
# 1                 0            0  2024-12-27T08:48:20.000000Z  -76.907348
# 2                 0            0  2024-03-18T09:40:41.000000Z  -70.421528
# 3                 0            0  2024-03-18T08:30:19.000000Z -119.135707
# 4                 0            0  2025-01-15T00:50:35.000000Z -122.885930
# 5                 0            0  2024-11-25T09:46:12.000000Z  -84.561916
# 6                 0            2  2024-03-18T10:01:10.000000Z -121.312584
# 7                 0            0  2024-03-18T11:51:53.000000Z  -84.743248
# 8                 0            0  2024-03-18T09:41:15.000000Z  -70.853720
# 9                 0            0  2024-03-18T10:53:09.000000Z -123.195717
# 10                0            0  2024-03-18T08:10:39.000000Z -122.046355
# 11                0            2  2024-03-18T09:11:16.000000Z -121.883386
# 12                0            0  2025-01-16T02:08:00.000000Z -122.604092
# 13                0            0  2024-03-18T09:40:52.000000Z  -71.196505
# 14                0            0  2024-03-18T08:10:37.000000Z  -88.314081
# 15                0            2  2024-03-18T09:11:44.000000Z -122.275199
# 16                0            0  2025-07-29T23:29:20.000000Z -105.517141
# 17                0            0  2024-03-18T06:50:18.000000Z  -83.287005
# 18                0            2  2024-03-18T09:20:24.000000Z -122.844209
# 19                0            0  2024-11-01T02:30:48.000000Z -117.968386
#
#     ...  city_id  category_id  category2_id  category3_id  short_description  \
# 0   ...       29          248           246           252
# 1   ...       55          246           247           248
# 2   ...       75          246           247           248
# 3   ...        3          246           247           248
# 4   ...       56          248           255           274
# 5   ...       46          256           246           248
# 6   ...       56          246           248           250
# 7   ...        9          246           248           255
# 8   ...       45          246           248           250
# 9   ...       41          246           248             0
# 10  ...        3          246           247           248
# 11  ...        3          248           255             0
# 12  ...       41          248           255           251
# 13  ...       45          246           248           250
# 14  ...       72          246           248           255
# 15  ...       41          248           254           255
# 16  ...    13514          252           274           248
# 17  ...       42          251           248           246
# 18  ...       56          248           255           252
# 19  ...        3          248             0           274
#
#                                                 image  \
# 0   https://static.where-e.com/United_States/Arizo...
# 1   https://static.where-e.com/United_States/Maryl...
# 2   https://static.where-e.com/United_States/Maine...
# 3   https://static.where-e.com/United_States/Calif...
# 4   https://static.where-e.com/United_States/Orego...
# 5   https://static.where-e.com/United_States/Georg...
# 6   https://static.where-e.com/United_States/Orego...
# 7   https://static.where-e.com/United_States/Ohio/...
# 8   https://static.where-e.com/United_States/Massa...
# 9   https://static.where-e.com/United_States/Washi...
# 10  https://static.where-e.com/United_States/Calif...
# 11  https://static.where-e.com/United_States/Calif...
# 12  https://static.where-e.com/United_States/Washi...
# 13  https://static.where-e.com/United_States/Massa...
# 14  https://static.where-e.com/United_States/Illin...
# 15  https://static.where-e.com/United_States/Washi...
# 16  https://static.where-e.com/United_States/Great...
# 17  https://static.where-e.com/United_States/North...
# 18  https://static.where-e.com/United_States/Orego...
# 19  https://www.wheree.com/assets/images/Wheree500...
#
#                                              openTime  \
# 0   [{'day_in_week': 3, 'time_open': 60, 'time_clo...
# 1   [{'day_in_week': 3, 'time_open': 32400, 'time_...
# 2                                                None
# 3   [{'day_in_week': 3, 'time_open': 32400, 'time_...
# 4   [{'day_in_week': 3, 'time_open': 21600, 'time_...
# 5   [{'day_in_week': 3, 'time_open': 32400, 'time_...
# 6                                                None
# 7                                                None
# 8   [{'day_in_week': 3, 'time_open': 60, 'time_clo...
# 9   [{'day_in_week': 3, 'time_open': 28800, 'time_...
# 10  [{'day_in_week': 3, 'time_open': 28800, 'time_...
# 11  [{'day_in_week': 3, 'time_open': 21600, 'time_...
# 12  [{'day_in_week': 3, 'time_open': 21600, 'time_...
# 13                                               None
# 14  [{'day_in_week': 3, 'time_open': 28800, 'time_...
# 15  [{'day_in_week': 3, 'time_open': 21600, 'time_...
# 16  [{'day_in_week': 3, 'time_open': 60, 'time_clo...
# 17                                               None
# 18  [{'day_in_week': 3, 'time_open': 21600, 'time_...
# 19  [{'day_in_week': 3, 'time_open': 19800, 'time_...
#
#                                               sub_cat affiliate  \
# 0   [{'id': 248, 'name': 'Gas Stations ', 'slug': ...      None
# 1   [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 2   [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 3   [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 4   [{'id': 248, 'name': 'Gas Stations ', 'slug': ...      None
# 5   [{'id': 256, 'name': 'Oil Change Stations ', '...      None
# 6   [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 7   [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 8   [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 9   [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 10  [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 11  [{'id': 248, 'name': 'Gas Stations ', 'slug': ...      None
# 12  [{'id': 248, 'name': 'Gas Stations ', 'slug': ...      None
# 13  [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 14  [{'id': 246, 'name': 'Auto Repair Services', '...      None
# 15  [{'id': 248, 'name': 'Gas Stations ', 'slug': ...      None
# 16  [{'id': 252, 'name': 'Parking Automotive', 'sl...      None
# 17  [{'id': 251, 'name': 'Tires Services', 'slug':...      None
# 18  [{'id': 248, 'name': 'Gas Stations ', 'slug': ...      None
# 19  [{'id': 248, 'name': 'Gas Stations ', 'slug': ...      None
#
#                                              city
# 0       {'id': 29, 'timezone': 'America/Phoenix'}
# 1      {'id': 55, 'timezone': 'America/New_York'}
# 2      {'id': 75, 'timezone': 'America/New_York'}
# 3    {'id': 3, 'timezone': 'America/Los_Angeles'}
# 4   {'id': 56, 'timezone': 'America/Los_Angeles'}
# 5      {'id': 46, 'timezone': 'America/New_York'}
# 6   {'id': 56, 'timezone': 'America/Los_Angeles'}
# 7       {'id': 9, 'timezone': 'America/New_York'}
# 8      {'id': 45, 'timezone': 'America/New_York'}
# 9   {'id': 41, 'timezone': 'America/Los_Angeles'}
# 10   {'id': 3, 'timezone': 'America/Los_Angeles'}
# 11   {'id': 3, 'timezone': 'America/Los_Angeles'}
# 12  {'id': 41, 'timezone': 'America/Los_Angeles'}
# 13     {'id': 45, 'timezone': 'America/New_York'}
# 14      {'id': 72, 'timezone': 'America/Chicago'}
# 15  {'id': 41, 'timezone': 'America/Los_Angeles'}
# 16                {'id': 13514, 'timezone': None}
# 17     {'id': 42, 'timezone': 'America/New_York'}
# 18  {'id': 56, 'timezone': 'America/Los_Angeles'}
# 19   {'id': 3, 'timezone': 'America/Los_Angeles'}
#
# [20 rows x 21 columns]
# Saved 6013 records to gas stations.csv

# %% [markdown]
# ## data Cleaning

# %%
import pandas as pd
import re

# %%
#cleang up
import ast  # safely evaluate string representation of list/dict


# Function to extract id and name
def extract_ids_and_names(detail_str):
    try:
        data_list = ast.literal_eval(detail_str)  # safely parse string to Python list
        return [(item['id'], item['name']) for item in data_list]
    except Exception as e:
        return None

# Apply the function to create new columns
df['extracted'] = df['sub_cat'].apply(extract_ids_and_names)

# Optional: separate into two new columns for clarity
df['ids'] = df['extracted'].apply(lambda x: [i[0] for i in x] if x else None)
df['names'] = df['extracted'].apply(lambda x: [i[1] for i in x] if x else None)

# Function to extract the first name
def extract_first_name(detail_str):
    try:
        data_list = ast.literal_eval(detail_str)  # convert string to list of dicts
        if isinstance(data_list, list) and len(data_list) > 0:
            return data_list[0].get('name')
    except Exception:
        return None
    return None

# Apply function
df['category'] = df['sub_cat'].apply(extract_first_name)

# Example pattern: captures two-letter state abbreviation before ZIP code
state_pattern = re.compile(r'\b([A-Z]{2})\b(?=\s*\d{5})')

def extract_state(address):
    """Extracts state abbreviation (e.g., FL, NY, CA) from address string."""
    if pd.isna(address):
        return None
    match = state_pattern.search(address)
    if match:
        return match.group(1)
    return None

# Apply function to your actual column
df['state'] = df['fulladdress'].apply(extract_state)

# %%
#cleaning data 
df.drop(columns=['alias', 'ranking', 'rating','city','number_of_rates', 'price_level','created_at','category_id', 'category2_id', 'category3_id','short_description', 'image', 'openTime', 'sub_cat', 'affiliate','extracted', 'ids'], inplace=True)
#RENAMING COLUMNS
df.rename(columns={
    
    'fulladdress': 'address',
    'names': 'categories',
    'category': 'sub_category',
    }, inplace=True)

df['categories'] = df['categories'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
df.head()
# Out:
#         id                                         name  \
# 0  1313022                          Petro Travel Center
# 1  1205397  AutoExpress Service Center-Beltsville Exxon
# 2   193653                    Bill Dodge Nissan Of Saco
# 3   121626                             Famoso Dragstrip
# 4  1315628                           Costco Gas Station
#
#                                              address   longitude   latitude  \
# 0  970 S Blake Ranch Rd, Kingman, AZ 86401, Unite... -113.788806  35.177913
# 1  11055 Baltimore Ave, Beltsville, MD 20705, Uni...  -76.907348  39.034232
# 2     852 Portland Rd, Saco, ME 04072, United States  -70.421528  43.538650
# 3  33559 Famoso Rd, McFarland, CA 93250, United S... -119.135707  35.600261
# 4  3075 Hamrick Rd, Central Point, OR 97502, Unit... -122.885930  42.372556
#
#    city_id                                         categories  \
# 0       29  Gas Stations , Auto Repair Services, Parking A...
# 1       55  Auto Repair Services, Towing Services, Gas Sta...
# 2       75  Auto Repair Services, Towing Services, Gas Sta...
# 3        3  Auto Repair Services, Towing Services, Gas Sta...
# 4       56  Gas Stations , Auto Parts & Supplies Services,...
#
#            sub_category state
# 0         Gas Stations     AZ
# 1  Auto Repair Services    MD
# 2  Auto Repair Services    ME
# 3  Auto Repair Services    CA
# 4         Gas Stations     OR

# %%
# copy
orgin_df = df.copy()

# %%
#filter the data sub_category
df = df[df['sub_category'].str.contains('Gas Stations', na=False)]
df.shape
# Out:
# (3188, 9)

# %%
df.head()
# Out:
#          id                 name  \
# 0   1313022  Petro Travel Center
# 4   1315628   Costco Gas Station
# 11   166452   Costco Gas Station
# 12  1321245   Costco Gas Station
# 15   169020   Costco Gas Station
#
#                                               address   longitude   latitude  \
# 0   970 S Blake Ranch Rd, Kingman, AZ 86401, Unite... -113.788806  35.177913
# 4   3075 Hamrick Rd, Central Point, OR 97502, Unit... -122.885930  42.372556
# 11  1709 Automation Pkwy, San Jose, CA 95131, Unit... -121.883386  37.388233
# 12  6720 NE 84th St, Vancouver, WA 98665, United S... -122.604092  45.684195
# 15  18109 33rd Ave W, Lynnwood, WA 98037, United S... -122.275199  47.833774
#
#     city_id                                         categories   sub_category  \
# 0        29  Gas Stations , Auto Repair Services, Parking A...  Gas Stations
# 4        56  Gas Stations , Auto Parts & Supplies Services,...  Gas Stations
# 11        3      Gas Stations , Auto Parts & Supplies Services  Gas Stations
# 12       41  Gas Stations , Auto Parts & Supplies Services,...  Gas Stations
# 15       41  Gas Stations , Car Wash Services, Auto Parts &...  Gas Stations
#
#    state
# 0     AZ
# 4     OR
# 11    CA
# 12    WA
# 15    WA

# %%
#create a copy of the df
df.to_csv("C:\\Users\\RodahNambuyaChepkori\\Documents\\Web Scrapping\\Data\\gas stations.csv", index=False)
print("✅ Changes appended (file updated successfully).")
# Out:
# ✅ Changes appended (file updated successfully).

# %%
# save the original dataframe
orgin_df.to_csv("C:\\Users\\RodahNambuyaChepkori\\Documents\\Web Scrapping\\Data\\original gas stations.csv", index=False)
print("✅ Original data saved successfully.")
# Out:
# ✅ Original data saved successfully.

# %% [markdown]
# # alternative link

# %% [markdown]
# url="https://gas-stations.cmac.ws/"

# %%
url="https://www.vaporana.com/directory/"
response = requests.get(url)
soup=BeautifulSoup(response.text, 'html.parser')
print(response.status_code)
# Out:
# 200

# %%
detail=soup.find_all('p')
for d in detail:
    links=d.find_all('a')
    name=d.get_text()
print(name, links)
# Out:
# Vape shops typically carry a wide range of products including e-cigarettes, vape pens, pod systems, box mods, tanks, coils, batteries, chargers, and e-liquids in various flavors and nicotine strengths. Many shops also sell accessories like cases, drip tips, and replacement parts. Some shops may specialize in certain brands or product types, so it's worth calling ahead if you're looking for something specific. []
